# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/titanic (1).csv",skiprows=4)

# %%
df.head()
# Out:
#    1  1.1  female  35.0  1.2  0     53.1  S  First  woman  False    C  \
# 0  0    3    male  35.0    0  0   8.0500  S  Third    man   True  NaN
# 1  0    3    male   NaN    0  0   8.4583  Q  Third    man   True  NaN
# 2  0    1    male  54.0    0  0  51.8625  S  First    man   True    E
# 3  0    3    male   2.0    3  1  21.0750  S  Third  child  False  NaN
# 4  1    3  female  27.0    0  2  11.1333  S  Third  woman  False  NaN
#
#    Southampton  yes  False.1
# 0  Southampton   no     True
# 1   Queenstown   no     True
# 2  Southampton   no     True
# 3  Southampton   no    False
# 4  Southampton  yes    False

# %%
df.columns
# Out:
# Index(['1', '1.1', 'female', '35.0', '1.2', '0', '53.1', 'S', 'First', 'woman',
#        'False', 'C', 'Southampton', 'yes', 'False.1'],
#       dtype='object')

# %%
#  Load clean Titanic dataset directly from Seaborn
df = sns.load_dataset('titanic')

# Keep only age and sex, drop missing
df = df[['age', 'sex']].dropna()
df.head()
# Out:
#     age     sex
# 0  22.0    male
# 1  38.0  female
# 2  26.0  female
# 3  35.0  female
# 4  35.0    male

# %%
# Histogram - Distribution of Age

plt.figure(figsize=(8,5))
sns.histplot(df['age'], kde=True, bins=20)
plt.title('Distribution of Passenger Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
# Bar Chart - Distribution of Sex

plt.figure(figsize=(6,4))
sns.countplot(x='sex', data=df, palette='pastel')
plt.title('Distribution of Passenger Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-264578225.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex', data=df, palette='pastel')
